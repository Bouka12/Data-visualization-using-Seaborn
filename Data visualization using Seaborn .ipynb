# %% [markdown]
# # Seaborn
#
#
# # Distribution plots
#
#  * distplot
#  * joinplot
#  * painplot
#
# ### Practice problem on IRIS dataset

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Correlation with Heatmap
#
#  A correlation heatmap uses colored cells, typically in a monochromatic scale, to show a 2D correlation matrix (table) between two discrete dimensions or event types. it is very important in Feature Selection

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# # JointPlot
# A joint plot allows to study the relationship between 2 numeric variables. The central chart display their correlation. it is usually a scatterplot, a hexbin plot, a 2D histogram or a 2D density plot

# %% [markdown]
# ## Univariate Analysis

# %%
sns.jointplot(x='tip',y='total_bill', data=df,kind='hex')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %% [markdown]
# # Pair Plot
# A "pairs plot" is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value, like this: Pairs plots are just elaborations on this, showing all variables paired with all the other variables

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# # Dist Plot
# #### Dist plot helps us to check the distribution of the columns feature

# %%
sns.distplot(df['tip'])

# %%
sns.distplot(df['tip'],kde=False,bins=10)

# %% [markdown]
# # Categorical Plots
# #### Seaborn also helps us in doing the analysis on Categorical Data points:
#  * boxplot
#  * violinplot
#  * countplot
#  * bar plot

# %%
## Count plot

sns.countplot('sex', data=df)

# %%
sns.countplot('day',data=df)

# %%
sns.countplot(y='sex',data=df)

# %%
## Bar Plot
sns.barplot(x='total_bill',y='sex',data=df)

# %%
sns.barplot(x='sex',y='total_bill',data=df)

# %% [markdown]
# # Box plot
#
#  A box and whisker plot (sometimes called a boxplot) is a graph that presents information from a five-number summary

# %%
sns.boxplot('smoker','total_bill',data=df)

# %%
sns.boxplot(x='day',y='total_bill',data=df, palette='rainbow')

# %%
sns.boxplot(data=df, orient='v')

# %%
# categories my data based on some other categories
sns.boxplot(x='total_bill', y='day',hue='smoker',data=df)

# %% [markdown]
# # Violin Plot
# Violin plot helps us to see both the distribution of data in terms of Kernel density estimation and the box plot

# %%
sns.violinplot(x='total_bill',y='day',data=df,palette='rainbow')

# %% [markdown]
# #  IRIS dataset visualisation
# #### using seaborn

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Correlation with heatmap

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr())

# %% [markdown]
# ### Correlation Interpretation:
# * petal_width and petal_length are highly positively correlated (corr=0.96 almost 1)
# * sepal_length and petal_length are correalted (+)
# * sepal_length and petal_width are correalted (+)
# * petal_width and sepal_width are correalted (-)
# * petal_length and sepal_width are correlated (-)
# * sepal_width and sepal_length are correlated (-)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## CountPlot

# %%
sns.countplot(x='sepal_width',data=iris)

# %%
sns.countplot(x='sepal_length',data=iris,palette='rainbow')

# %%
sns.countplot(x='petal_width',data=iris, palette='rainbow')

# %%
sns.countplot(x='petal_length',data=iris,palette="Set3")

# %%
sns.countplot(x='species',data=iris,palette="Set3")

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Joint Plot

# %%
#jointplot
sns.jointplot(x="petal_length", y="sepal_length", data=iris, kind='hex'
   , color="g")

# %%
#jointplot
sns.jointplot(x='petal_width', y='sepal_width',data=iris, kind="hex")

# %% [markdown]
# ## BoxPlot

# %%
#boxplot
sns.boxplot(x='species',y='sepal_length',data=iris,palette='rainbow')

# %%
sns.boxplot(x='species',y='sepal_width',data=iris,palette='Set3')

# %%
sns.boxplot(x='species',y='petal_width',data=iris,palette='Set2')

# %%
sns.boxplot(x='species',y='petal_length',data=iris,palette='Set1')

# %% [markdown]
# ## ViolinPlot

# %%
sns.violinplot(y='species',x='petal_width',data=iris,palette='rainbow')

# %%
sns.violinplot(y='species',x='petal_length',data=iris,palette='rainbow')

# %%
sns.violinplot(y='species',x='sepal_width',data=iris,palette='Set2')

# %%
sns.violinplot(y='species',x='sepal_length',data=iris,palette='Set3')

# %% [markdown]
# ## Barplot

# %%
#Barplot
sns.barplot(x='species',y='petal_width',data=iris, palette="Blues_d")

# %%
sns.barplot(x='species',y='petal_length',data=iris, palette="rainbow")

# %%
sns.barplot(x='species',y='sepal_width',data=iris, palette="Set3")

# %%
sns.barplot(x='species',y='sepal_length',data=iris, palette="Set2")
